# %%
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from os import environ

# %%
engine = create_engine('sqlite:///landon.sqlite')

# %%
sales_df = pd.read_sql_table('sales', con=engine.connect(), index_col='order_id')

# %%
sales_df.head()
# Out:
#           property_id property_city property_state  product_id  \
# order_id
# 1                  17     Las Vegas         Nevada          41
# 2                  15       Chicago       Illinois          54
# 3                   5   Kansas City       Missouri          71
# 4                  19   Los Angeles     California           3
# 5                  12        Dallas          Texas          45
#
#          product_category      product_name  quantity  product_price  \
# order_id
# 1             Furnishings      Office Chair         1           85.0
# 2             Furnishings  Chest of Drawers         2          150.0
# 3             Maintenance            Hammer         2           17.0
# 4            Housekeeping         Washcloth         2            3.0
# 5             Furnishings     Computer Desk         3          102.0
#
#           order_total
# order_id
# 1                85.0
# 2               300.0
# 3                34.0
# 4                 6.0
# 5               306.0

# %%
sales_df.sort_values('order_total')
# Out:
#           property_id property_city property_state  product_id  \
# order_id
# 3768               18       Phoenix        Arizona          81
# 2027                2    Cincinnati           Ohio          81
# 423                 4       Seattle     Washington          22
# 4482               19   Los Angeles     California          81
# 4581               13   New Orleans      Louisiana          81
# ...               ...           ...            ...         ...
# 2743               16        Denver       Colorado          37
# 774                11       Atlanta        Georgia          37
# 2755               14     Nashville      Tennessee          37
# 1980               12        Dallas          Texas          37
# 1723                1      New York       New York          37
#
#          product_category  product_name  quantity  product_price  order_total
# order_id
# 3768         Public Areas  Flyer Holder         1            3.0          3.0
# 2027         Public Areas  Flyer Holder         1            3.0          3.0
# 423       Office Supplies   Paper Clips         1            3.0          3.0
# 4482         Public Areas  Flyer Holder         1            3.0          3.0
# 4581         Public Areas  Flyer Holder         1            3.0          3.0
# ...                   ...           ...       ...            ...          ...
# 2743          Furnishings    Bed (King)         3          300.0        900.0
# 774           Furnishings    Bed (King)         3          300.0        900.0
# 2755          Furnishings    Bed (King)         3          300.0        900.0
# 1980          Furnishings    Bed (King)         3          300.0        900.0
# 1723          Furnishings    Bed (King)         3          300.0        900.0
#
# [5000 rows x 9 columns]

# %%
sales_df['property_state'].value_counts()
# Out:
# property_state
# California       505
# Virginia         504
# Pennsylvania     272
# Missouri         267
# Nevada           261
# Louisiana        260
# Washington       257
# Illinois         257
# Tennessee        257
# Ohio             254
# Georgia          253
# Texas            252
# Florida          238
# Massachusetts    237
# Colorado         235
# Arizona          233
# Oregon           231
# New York         227
# Name: count, dtype: int64

# %%
sales_df['property_state'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='property_state'>

# %%
plt.pie(sales_df['property_state'].value_counts().head(10), 
        labels=sales_df['property_state'].value_counts().head(10).index.tolist())
# Out:
# ([<matplotlib.patches.Wedge at 0x19af3b902d0>,
#   <matplotlib.patches.Wedge at 0x19af3c0b0d0>,
#   <matplotlib.patches.Wedge at 0x19af3c1c090>,
#   <matplotlib.patches.Wedge at 0x19af3c1cfd0>,
#   <matplotlib.patches.Wedge at 0x19af3c1df50>,
#   <matplotlib.patches.Wedge at 0x19af3c1f150>,
#   <matplotlib.patches.Wedge at 0x19af3c1ff50>,
#   <matplotlib.patches.Wedge at 0x19af3c2ced0>,
#   <matplotlib.patches.Wedge at 0x19af3c2dc90>,
#   <matplotlib.patches.Wedge at 0x19af3c1ef50>],
#  [Text(0.9585288546080237, 0.5396502894318046, 'California'),
#   Text(0.03685142488712066, 1.0993825414676135, 'Virginia'),
#   Text(-0.7533600471128238, 0.8015289386005748, 'Pennsylvania'),
#   Text(-1.0604185785239426, 0.2924250986513661, 'Missouri'),
#   Text(-1.0610101836456403, -0.2902712355715684, 'Nevada'),
#   Text(-0.7694806075353592, -0.7860658971275976, 'Louisiana'),
#   Text(-0.27191402797249314, -1.0658624495645648, 'Washington'),
#   Text(0.2956541753339997, -1.059522821182995, 'Illinois'),
#   Text(0.7845016796352393, -0.7710752976522386, 'Tennessee'),
#   Text(1.0636185489465253, -0.2805629739236593, 'Ohio')])
