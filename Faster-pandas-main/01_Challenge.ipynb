# %%
# %run bid_diff.py

# %%
median_diff('Fontes/bids.csv.xz')
# Out:
# 0.013655841283122139

# %%
# %prun -s cumulative median_diff('Fontes/bids.csv.xz')
# Out:
#          509292 function calls (509245 primitive calls) in 1.230 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.230    1.230 {built-in method builtins.exec}
#         1    0.001    0.001    1.230    1.230 <string>:1(<module>)
#         1    0.001    0.001    1.229    1.229 bid_diff.py:19(median_diff)
#         1    0.000    0.000    0.733    0.733 readers.py:848(read_csv)
#         1    0.001    0.001    0.733    0.733 readers.py:574(_read)
#         1    0.000    0.000    0.715    0.715 readers.py:1732(read)
#         1    0.000    0.000    0.709    0.709 c_parser_wrapper.py:222(read)
#         1    0.168    0.168    0.704    0.704 {method 'read_low_memory' of 'pandas._libs.parsers.TextReader' objects}
#       812    0.001    0.000    0.543    0.001 lzma.py:202(read1)
#       812    0.005    0.000    0.541    0.001 {method 'read1' of '_io.BufferedReader' objects}
# ...
