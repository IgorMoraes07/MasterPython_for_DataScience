# %%
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
import matplotlib as mp

# %%
daterange = pd.period_range('1/1/1950', freq='1d', periods=50)
date_df = pd.DataFrame(data=daterange,columns=['day'])
date_df['value1'] = np.random.randint(45,65,size=(len(date_df)))
date_df['value2'] = np.random.randint(25,35,size=(len(date_df)))
date_df.head(3)
# Out:
#           day  value1  value2
# 0  1950-01-01      62      32
# 1  1950-01-02      52      29
# 2  1950-01-03      60      25

# %%
ax = date_df.plot()

# %%
date_df.plot.area(stacked=True)
# Out:
# <Axes: >

# %%
iris = pd.read_csv('Fontes/iris.csv')
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 62            6.0          2.2           4.0          1.0  versicolor
# 128           6.4          2.8           5.6          2.1   virginica
# 135           7.7          3.0           6.1          2.3   virginica
# 9             4.9          3.1           1.5          0.1      setosa
# 79            5.7          2.6           3.5          1.0  versicolor

# %%
iris.hist()

# %%
iris[['sepal_width','sepal_length']].plot.hist(alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
colors = {"versicolor":"red","setosa":"green","virginica":"blue"}
iris['colors'] = iris['species'].map(colors)
iris.plot.scatter(x='sepal_width', y='sepal_length', color=iris['colors'])
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
scatter_matrix(iris,figsize=(15, 9),)
# Out:
# array([[<Axes: xlabel='sepal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_width'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_length'>,
#         <Axes: xlabel='petal_length', ylabel='petal_length'>,
#         <Axes: xlabel='petal_width', ylabel='petal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_width'>,
#         <Axes: xlabel='petal_length', ylabel='petal_width'>,
#         <Axes: xlabel='petal_width', ylabel='petal_width'>]], dtype=object)

# %%
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species colors
# 0           5.1          3.5           1.4          0.2  setosa  green
# 1           4.9          3.0           1.4          0.2  setosa  green
# 2           4.7          3.2           1.3          0.2  setosa  green

# %%
iris.mean(numeric_only=True)
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
iris.median(numeric_only=True)
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
iris.mode()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species colors
# 0           5.0          3.0           1.4          0.2      setosa   blue
# 1           NaN          NaN           1.5          NaN  versicolor  green
# 2           NaN          NaN           NaN          NaN   virginica    red

# %%
iris.std(numeric_only=True)
# Out:
# sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# dtype: float64

# %%
iris.boxplot();

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.corr(numeric_only=True)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
iris.corr(numeric_only=True).style.background_gradient(cmap='RdYlGn', axis=None)
# Out:
# <style type="text/css">
# #T_e27e3_row0_col0, #T_e27e3_row1_col1, #T_e27e3_row2_col2, #T_e27e3_row3_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_e27e3_row0_col1, #T_e27e3_row1_col0 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_e27e3_row0_col2, #T_e27e3_row2_col0 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_e27e3_row0_col3, #T_e27e3_row3_col0 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_e27e3_row1_col2, #T_e27e3_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_e27e3_row1_col3, #T_e27e3_row3_col1 {
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# #T_e27e3_row2_col3, #T_e27e3_row3_col2 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e27e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e27e3_level0_col0" class="col_heading level0 col0" >sepal_length</th>
#       <th id="T_e27e3_level0_col1" class="col_heading level0 col1" >sepal_width</th>
#       <th id="T_e27e3_level0_col2" class="col_heading level0 col2" >petal_length</th>
#       <th id="T_e27e3_level0_col3" class="col_heading level0 col3" >petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e27e3_level0_row0" class="row_heading level0 row0" >sepal_length</th>
#       <td id="T_e27e3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e27e3_row0_col1" class="data row0 col1" >-0.117570</td>
#       <td id="T_e27e3_row0_col2" class="data row0 col2" >0.871754</td>
#       <td id="T_e27e3_row0_col3" class="data row0 col3" >0.817941</td>
#     </tr>
#     <tr>
#       <th id="T_e27e3_level0_row1" class="row_heading level0 row1" >sepal_width</th>
#       <td id="T_e27e3_row1_col0" class="data row1 col0" >-0.117570</td>
#       <td id="T_e27e3_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e27e3_row1_col2" class="data row1 col2" >-0.428440</td>
#       <td id="T_e27e3_row1_col3" class="data row1 col3" >-0.366126</td>
#     </tr>
#     <tr>
#       <th id="T_e27e3_level0_row2" class="row_heading level0 row2" >petal_length</th>
#       <td id="T_e27e3_row2_col0" class="data row2 col0" >0.871754</td>
#       <td id="T_e27e3_row2_col1" class="data row2 col1" >-0.428440</td>
#       <td id="T_e27e3_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e27e3_row2_col3" class="data row2 col3" >0.962865</td>
#     </tr>
#     <tr>
#       <th id="T_e27e3_level0_row3" class="row_heading level0 row3" >petal_width</th>
#       <td id="T_e27e3_row3_col0" class="data row3 col0" >0.817941</td>
#       <td id="T_e27e3_row3_col1" class="data row3 col1" >-0.366126</td>
#       <td id="T_e27e3_row3_col2" class="data row3 col2" >0.962865</td>
#       <td id="T_e27e3_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
